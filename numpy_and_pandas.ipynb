# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('auto-mpg (3).csv')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpg = data['mpg'].to_numpy()  # mpg column into numpy array

# %% [markdown]
# ### basic array operation

# %%
np.mean(mpg)
# Out:
# np.float64(23.514572864321607)

# %%
np.median(mpg)
# Out:
# np.float64(23.0)

# %%
np.std(mpg)
# Out:
# np.float64(7.806159061274433)

# %%
np.sum(mpg > 25)
# Out:
# np.int64(158)

# %% [markdown]
# ### filtering

# %%
print(data.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
filtered = data[data['cylinders'] > 6]
car_names = filtered['car name'].tolist()
print(car_names)
# Out:
# ['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite', 'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se', "plymouth 'cuda 340", 'chevrolet monte carlo', 'buick estate wagon (sw)', 'ford f250', 'chevy c20', 'dodge d200', 'hi 1200d', 'chevrolet impala', 'pontiac catalina brougham', 'ford galaxie 500', 'plymouth fury iii', 'dodge monaco (sw)', 'ford country squire (sw)', 'pontiac safari (sw)', 'chevrolet impala', 'pontiac catalina', 'plymouth fury iii', 'ford galaxie 500', 'amc ambassador sst', 'mercury marquis', 'buick lesabre custom', 'oldsmobile delta 88 royale', 'chrysler newport royal', 'amc matador (sw)', 'chevrolet chevelle concours (sw)', 'ford gran torino (sw)', 'plymouth satellite custom (sw)', 'buick century 350', 'amc matador', 'chevrolet malibu', 'ford gran torino', 'dodge coronet custom', 'mercury marquis brougham', 'chevrolet caprice classic', 'ford ltd', 'plymouth fury gran sedan', 'chrysler new yorker brougham', 'buick electra 225 custom', 'amc ambassador brougham', 'chevrolet impala', 'ford country', 'plymouth custom suburb', 'oldsmobile vista cruiser', 'chevrolet monte carlo s', 'pontiac grand prix', 'dodge dart custom', 'oldsmobile omega', 'ford gran torino', 'buick century luxus (sw)', 'dodge coronet custom (sw)', 'ford gran torino (sw)', 'amc matador (sw)', 'pontiac catalina', 'chevrolet bel air', 'plymouth grand fury', 'ford ltd', 'chevrolet monza 2+2', 'ford mustang ii', 'chevrolet chevelle malibu classic', 'dodge coronet brougham', 'amc matador', 'ford gran torino', 'plymouth volare premier v8', 'cadillac seville', 'chevy c10', 'ford f108', 'dodge d100', 'chevrolet caprice classic', 'oldsmobile cutlass supreme', 'dodge monaco brougham', 'mercury cougar brougham', 'pontiac grand prix lj', 'chevrolet monte carlo landau', 'chrysler cordoba', 'ford thunderbird', 'oldsmobile cutlass salon brougham', 'dodge diplomat', 'mercury monarch ghia', 'chevrolet monte carlo landau', 'ford futura', 'dodge magnum xe', 'chevrolet caprice classic', 'ford ltd landau', 'mercury grand marquis', 'dodge st. regis', 'buick estate wagon (sw)', 'ford country squire (sw)', 'chevrolet malibu classic (sw)', 'chrysler lebaron town @ country (sw)', 'cadillac eldorado', 'oldsmobile cutlass salon brougham', 'oldsmobile cutlass ls']

# %% [markdown]
# ### Statistical Analysis

# %%
weight = data['weight'].to_numpy()
percentiles = np.percentile(weight, [25, 50, 75])
print(percentiles)
# Out:
# [2223.75 2803.5  3608.  ]

# %% [markdown]
# ### Array manipulation

# %%
#  '70707070707070707070' '65656565656565656565' '69696969696969696969'
#  '90909090909090909090' '115115115115115115115115115115'
#  '115115115115115115115115115115' '90909090909090909090'
#  '76767676767676767676' '60606060606060606060' '70707070707070707070'
#  '65656565656565656565' '90909090909090909090' '88888888888888888888'
#  '90909090909090909090' '90909090909090909090' '78787878787878787878'
#  '90909090909090909090' '75757575757575757575' '92929292929292929292'
#  '75757575757575757575' '65656565656565656565'
#  '105105105105105105105105105105' '65656565656565656565'
#  '48484848484848484848' '48484848484848484848' '67676767676767676767'
#  '67676767676767676767' '67676767676767676767' '??????????'
#  '67676767676767676767' '62626262626262626262'
#  '132132132132132132132132132132' '100100100100100100100100100100'
#  '88888888888888888888' '??????????' '72727272727272727272'
#  '84848484848484848484' '84848484848484848484' '92929292929292929292'
#  '110110110110110110110110110110' '84848484848484848484'
#  '58585858585858585858' '64646464646464646464' '60606060606060606060'
#  '67676767676767676767' '65656565656565656565' '62626262626262626262'
#  '68686868686868686868' '63636363636363636363' '65656565656565656565'
#  '65656565656565656565' '74747474747474747474' '??????????'
#  '75757575757575757575' '75757575757575757575'
#  '100100100100100100100100100100' '74747474747474747474'
#  '80808080808080808080' '76767676767676767676'
#  '116116116116116116116116116116' '120120120120120120120120120120'
#  '110110110110110110110110110110' '105105105105105105105105105105'
#  '88888888888888888888' '85858585858585858585' '88888888888888888888'
#  '88888888888888888888' '88888888888888888888' '85858585858585858585'
#  '84848484848484848484' '90909090909090909090' '92929292929292929292'
#  '??????????' '74747474747474747474' '68686868686868686868'
#  '68686868686868686868' '63636363636363636363' '70707070707070707070'
#  '88888888888888888888' '75757575757575757575' '70707070707070707070'
#  '67676767676767676767' '67676767676767676767' '67676767676767676767'
#  '110110110110110110110110110110' '85858585858585858585'
#  '92929292929292929292' '112112112112112112112112112112'
#  '96969696969696969696' '84848484848484848484' '90909090909090909090'
#  '86868686868686868686' '52525252525252525252' '84848484848484848484'
#  '79797979797979797979' '82828282828282828282']

# %% [markdown]
# ### Correlation

# %%
corr = np.corrcoef(data['mpg'], data['weight'])
print(corr)
# Out:
# [[ 1.         -0.83174093]
#  [-0.83174093  1.        ]]

# %% [markdown]
# ### Conditional Aggregates

# %%
mean_mpg_cyn = data.groupby('cylinders')['mpg'].mean()
print(mean_mpg_cyn)
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
mean_mpg_cyn = data.groupby('cylinders')['mpg'].mean()
mean_mpg_cyn.mean()
# Out:
# np.float64(22.430450490875963)

# %% [markdown]
# # pandas

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
data.head(10)    # The first 10 rows
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 5       1           ford galaxie 500
# 6       1           chevrolet impala
# 7       1          plymouth fury iii
# 8       1           pontiac catalina
# 9       1         amc ambassador dpl

# %%
data.shape      # The total number of rows and columns
# Out:
# (398, 9)

# %%
data.describe()    # summary statistics for numerical columns
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# Filtering and Indexing
filtered_data = data.loc[(data['model year'] == 75)&(data['weight']) < 3000,['car name','weight','mpg']]
print(filtered_data)
# Out:
#                       car name  weight   mpg
# 0    chevrolet chevelle malibu    3504  18.0
# 1            buick skylark 320    3693  15.0
# 2           plymouth satellite    3436  18.0
# 3                amc rebel sst    3433  16.0
# 4                  ford torino    3449  17.0
# ..                         ...     ...   ...
# 393            ford mustang gl    2790  27.0
# 394                  vw pickup    2130  44.0
# 395              dodge rampage    2295  32.0
# 396                ford ranger    2625  28.0
# 397                 chevy s-10    2720  31.0
#
# [398 rows x 3 columns]

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# handling Missing Data
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
# Group By
g = data.groupby("origin")

# %%
g["mpg"].mean()
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %%
# sorting

data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.sort_values(by='mpg',ascending=False)[['car name','mpg']].head(10)
# Out:
#                             car name   mpg
# 322                        mazda glc  46.6
# 329              honda civic 1500 gl  44.6
# 325             vw rabbit c (diesel)  44.3
# 394                        vw pickup  44.0
# 326               vw dasher (diesel)  43.4
# 244  volkswagen rabbit custom diesel  43.1
# 309                        vw rabbit  41.5
# 330             renault lecar deluxe  40.9
# 324                       datsun 210  40.8
# 247                   datsun b210 gx  39.4

# %%
# apply fuction

def performance_score(row):
    return row['mpg'] * row['acceleration'] / row['weight']

# %%
data['performance_score'] = data.apply(performance_score, axis=1)
print(data[['car name', 'mpg', 'acceleration', 'weight', 'performance_score']].head())
# Out:
#                     car name   mpg  acceleration  weight  performance_score
# 0  chevrolet chevelle malibu  18.0          12.0    3504           0.061644
# 1          buick skylark 320  15.0          11.5    3693           0.046710
# 2         plymouth satellite  18.0          11.0    3436           0.057625
# 3              amc rebel sst  16.0          12.0    3433           0.055928
# 4                ford torino  17.0          10.5    3449           0.051754

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  performance_score
# 0            70       1  chevrolet chevelle malibu           0.061644
# 1            70       1          buick skylark 320           0.046710
# 2            70       1         plymouth satellite           0.057625
# 3            70       1              amc rebel sst           0.055928
# 4            70       1                ford torino           0.051754
# ..          ...     ...                        ...                ...
# 393          82       1            ford mustang gl           0.150968
# 394          82       2                  vw pickup           0.508169
# 395          82       1              dodge rampage           0.161743
# 396          82       1                ford ranger           0.198400
# 397          82       1                 chevy s-10           0.221103
#
# [398 rows x 10 columns]

# %%
# exporting data
high_mpg_cars = data[data['mpg'] > 30][['mpg', 'cylinders', 'horsepower', 'weight']]
high_mpg_cars.to_csv('high_mpg_cars.csv')
print(high_mpg_cars)
# Out:
#       mpg  cylinders horsepower  weight
# 53   31.0          4         65    1773
# 54   35.0          4         69    1613
# 129  31.0          4         67    1950
# 131  32.0          4         65    1836
# 144  31.0          4         52    1649
# ..    ...        ...        ...     ...
# 390  32.0          4         96    2665
# 391  36.0          4         84    2370
# 394  44.0          4         52    2130
# 395  32.0          4         84    2295
# 397  31.0          4         82    2720
#
# [85 rows x 4 columns]

# %%
#finding anomalies
Q1 = data['mpg'].quantile(0.25)
Q3 = data['mpg'].quantile(0.75)
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
outliers = data[(data['mpg'] < lower_bound) | (data['mpg'] > upper_bound)]
print(outliers[['car name', 'mpg', 'model year']])
# Out:
#       car name   mpg  model year
# 322  mazda glc  46.6          80
