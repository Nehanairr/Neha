# %% [markdown]
# ### pandas problem

# %%
import pandas as pd

# %%
data = pd.read_csv('auto-mpg (3).csv')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### 1 basic Exploration

# %%
data.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# ...

# %%
data.shape
# Out:
# (398, 9)

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### 4 Data Transformation

# %%
cols_selected = ['horsepower', 'weight']
power_to_weight_ratio = data[cols_selected]
power_to_weight_ratio.to_csv('power_to_weight_ratio.csv', index=False)

# %% [markdown]
# ### 6 sorting

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year  origin                   car name  power_to_weight_ratio
# 0          70       1  chevrolet chevelle malibu               0.037100
# 1          70       1          buick skylark 320               0.044679
# 2          70       1         plymouth satellite               0.043655
# 3          70       1              amc rebel sst               0.043694
# 4          70       1                ford torino               0.040591

# %%
data.sort_values(by='mpg',ascending=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
# ..    ...        ...           ...         ...     ...           ...
# 67   11.0          8         429.0       208.0    4633          11.0
# 27   11.0          8         318.0       210.0    4382          13.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 28    9.0          8         304.0       193.0    4732          18.5
#
#      model year  origin              car name  power_to_weight_ratio
# 322          80       3             mazda glc               0.030806
# ...

# %%
data.sort_values(by='mpg')['car name'][0:10]
# Out:
# 28                     hi 1200d
# 25                    ford f250
# 26                    chevy c20
# 67              mercury marquis
# 27                   dodge d200
# 103            chevrolet impala
# 124            oldsmobile omega
# 42            dodge monaco (sw)
# 95     buick electra 225 custom
# 104                ford country
# Name: car name, dtype: object

# %% [markdown]
# ### 3 Handling Missing Data

# %%
data.isna().sum()
# Out:
# mpg                      0
# cylinders                0
# displacement             0
# horsepower               6
# weight                   0
# acceleration             0
# model year               0
# origin                   0
# car name                 0
# power_to_weight_ratio    6
# dtype: int64

# %% [markdown]
# ### 2 Filtering and Indexing

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name  power_to_weight_ratio
# ...

# %%
data.loc[(data['model year'] == 75) & (data['weight'] < 3000), ['car name', 'weight', 'mpg']]
# Out:
#               car name  weight   mpg
# 167     toyota corolla    2171  29.0
# 168         ford pinto    2639  23.0
# 169        amc gremlin    2914  20.0
# 170      pontiac astro    2592  23.0
# 171      toyota corona    2702  24.0
# 172  volkswagen dasher    2223  25.0
# 173         datsun 710    2545  24.0
# 174         ford pinto    2984  18.0
# 175  volkswagen rabbit    1937  29.0
# 177         audi 100ls    2694  23.0
# 178        peugeot 504    2957  23.0
# 179        volvo 244dl    2945  22.0
# 180          saab 99le    2671  25.0
# 181   honda civic cvcc    1795  33.0

# %% [markdown]
# ### 5 group by

# %%
g = data.groupby("origin")

# %%
g["mpg"].mean()
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64
