# %%
import pandas as pd

# %%
data = pd.read_csv ('auto-mpg.csv')

# %%
# type(data)

# %%
data.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
data.tail(3)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin       car name
# 395          82       1  dodge rampage
# 396          82       1    ford ranger
# 397          82       1     chevy s-10

# %%
data.shape
# Out:
# (398, 9)

# %%
data.shape[1]
# Out:
# 9

# %%
data.columns.tolist()
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model year',
#  'origin',
#  'car name']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.head(1)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu

# %%
data[ 'model year']
# Out:
# 0      70
# 1      70
# 2      70
# 3      70
# 4      70
#        ..
# 393    82
# 394    82
# 395    82
# 396    82
# 397    82
# Name: model year, Length: 398, dtype: int64

# %%
data[ 'weight']
# Out:
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
#        ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
# Name: weight, Length: 398, dtype: int64

# %%
data[ 'model year'].value_counts().index
# Out:
# Index([73, 78, 76, 82, 75, 80, 79, 81, 70, 71, 72, 77, 74], dtype='int64', name='model year')

# %%
data[['mpg', 'weight']]
# Out:
#       mpg  weight
# 0    18.0    3504
# 1    15.0    3693
# 2    18.0    3436
# 3    16.0    3433
# 4    17.0    3449
# ..    ...     ...
# 393  27.0    2790
# 394  44.0    2130
# 395  32.0    2295
# 396  28.0    2625
# 397  31.0    2720
#
# [398 rows x 2 columns]

# %%
cols_selected = ['weight','mpg']
small_data = data[cols_selected]

# %%
small_data
# Out:
#      weight   mpg
# 0      3504  18.0
# 1      3693  15.0
# 2      3436  18.0
# 3      3433  16.0
# 4      3449  17.0
# ..      ...   ...
# 393    2790  27.0
# 394    2130  44.0
# 395    2295  32.0
# 396    2625  28.0
# 397    2720  31.0
#
# [398 rows x 2 columns]

# %%
small_data.to_csv('small_data.csv')

# %%
small_data.to_excel('small_data.xlsx')

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.isna()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin  car name
# 0         False   False     False
# 1         False   False     False
# ...

# %%
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data['kmpl'] = data['mpg']*0.42514370

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name      kmpl
# 0       1  chevrolet chevelle malibu  7.652587
# 1       1          buick skylark 320  6.377156
# 2       1         plymouth satellite  7.652587
# 3       1              amc rebel sst  6.802299
# 4       1                ford torino  7.227443

# %%
data = data.sort_values(by='kmpl', ascending=False)

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
# ..    ...        ...           ...        ...     ...           ...
# 67   11.0          8         429.0        208    4633          11.0
# 27   11.0          8         318.0        210    4382          13.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin              car name       kmpl
# 322          80       3             mazda glc  19.811696
# ...

# %%
data.sort_values(by='weight')['car name'][0:2]
# Out:
# 54       datsun 1200
# 144    toyota corona
# Name: car name, dtype: object

# %%
import numpy as np
simple_data = {
    'col1': [1 ,2 ,3 ,4],
    'col2': ['A','B','C','D']}
df = pd.DataFrame(simple_data, index=[2,7,8,1])

# %%
df
# Out:
#    col1 col2
# 2     1    A
# 7     2    B
# 8     3    C
# 1     4    D

# %%
df.loc[1]    # loc gets the rows of corresponding to the index value passed
# Out:
# col1    4
# col2    D
# Name: 1, dtype: object

# %%
df.iloc[0]   # iloc gets the rows of corresponding to the positional value passed
# Out:
# col1    1
# col2    A
# Name: 2, dtype: object

# %%
data.iloc[:,:2]
# Out:
#       mpg  cylinders
# 322  46.6          4
# 329  44.6          4
# 325  44.3          4
# 394  44.0          4
# 326  43.4          4
# ..    ...        ...
# 67   11.0          8
# 27   11.0          8
# 25   10.0          8
# 26   10.0          8
# 28    9.0          8
#
# [398 rows x 2 columns]

# %%
# rows 300 & 301, columns:2&3
data.iloc[300:302,2:4]
# Out:
#      displacement horsepower
# 222         260.0        110
# 4           302.0        140

# %%
logical_expression = data['kmpl']<7
data[logical_expression]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 277  16.2          6         163.0        133    3410          15.8
# 3    16.0          8         304.0        150    3433          12.0
# 156  16.0          8         400.0        170    4668          11.5
# 158  16.0          8         318.0        150    4498          14.5
# 232  16.0          8         351.0        149    4335          14.5
# ..    ...        ...           ...        ...     ...           ...
# 67   11.0          8         429.0        208    4633          11.0
# 27   11.0          8         318.0        210    4382          13.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin             car name      kmpl
# 277          78       2        peugeot 604sl  6.887328
# ...

# %%
boolean_expr= (data['kmpl']<20) & (data['model year']<80)

# %%
data[boolean_expr]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 244  43.1          4          90.0         48    1985          21.5
# 247  39.4          4          85.0         70    2070          18.6
# 304  37.3          4          91.0         69    2130          14.7
# 248  36.1          4          91.0         60    1800          16.4
# 245  36.1          4          98.0         66    1800          14.4
# ..    ...        ...           ...        ...     ...           ...
# 67   11.0          8         429.0        208    4633          11.0
# 27   11.0          8         318.0        210    4382          13.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin                         car name       kmpl
# 244          78       2  volkswagen rabbit custom diesel  18.323693
# ...

# %%
g = data.groupby("model year")

# %%
g.max()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# model year
# 70          27.0          8         455.0         97    4732          20.5
# 71          35.0          8         400.0          ?    5140          20.5
# 72          28.0          8         429.0         97    4633          23.5
# 73          29.0          8         455.0         95    4997          21.0
# 74          32.0          8         350.0          ?    4699          21.0
# 75          33.0          8         400.0         98    4668          21.0
# 76          33.0          8         351.0         95    4380          22.2
# 77          36.0          8         400.0         98    4335          19.0
# 78          43.1          8         318.0         97    4080          21.5
# 79          37.3          8         360.0         90    4360          24.8
# 80          46.6          6         225.0          ?    3381          23.7
# ...

# %%
for idx, row in data.iterrows():
  print(idx, row)
  break
# Out:
# 322 mpg                  46.6
# cylinders               4
# displacement         86.0
# horsepower             65
# weight               2110
# acceleration         17.9
# model year             80
# origin                  3
# car name        mazda glc
# kmpl            19.811696
# Name: 322, dtype: object

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
# ..    ...        ...           ...        ...     ...           ...
# 67   11.0          8         429.0        208    4633          11.0
# 27   11.0          8         318.0        210    4382          13.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin              car name       kmpl
# 322          80       3             mazda glc  19.811696
# ...

# %%
data["model year"].unique()
# Out:
# array([80, 82, 78, 81, 79, 77, 71, 75, 76, 74, 73, 72, 70])

# %%
data.values
# Out:
# array([[46.6, 4, 86.0, ..., 3, 'mazda glc', 19.81169642],
#        [44.6, 4, 91.0, ..., 3, 'honda civic 1500 gl', 18.96140902],
#        [44.3, 4, 90.0, ..., 2, 'vw rabbit c (diesel)', 18.83386591],
#        ...,
#        [10.0, 8, 360.0, ..., 1, 'ford f250', 4.251437],
#        [10.0, 8, 307.0, ..., 1, 'chevy c20', 4.251437],
#        [9.0, 8, 304.0, ..., 1, 'hi 1200d', 3.8262933]], dtype=object)

# %%
car_new = data.drop(["car name", "kmpl"], axis= 1)

# %%
car_new
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
# ..    ...        ...           ...        ...     ...           ...
# 67   11.0          8         429.0        208    4633          11.0
# 27   11.0          8         318.0        210    4382          13.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin
# 322          80       3
# 329          80       3
# 325          80       2
# 394          82       2
# ...

# %%
data[~(data['weight']>4000)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
# ..    ...        ...           ...        ...     ...           ...
# 214  13.0          8         302.0        130    3870          15.0
# 208  13.0          8         318.0        150    3940          13.2
# 87   13.0          8         350.0        145    3988          13.0
# 96   13.0          8         360.0        175    3821          11.0
# 124  11.0          8         350.0        180    3664          11.0
#
#      model year  origin                    car name       kmpl
# 322          80       3                   mazda glc  19.811696
# ...
